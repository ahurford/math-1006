# %% [markdown]
# **Generating the logistic sequence in SageMath**
#
# Example 8. p97 in BioCalculus by Stewart and Day.
#
# c = 2.8 and $x_0 = 0.8$

# %%
var('a')
def a(n):
    if n==0:
            return 0.8
    else:
            return 2.8*a(n-1)*(1-a(n-1))

# %%
data=[a(n) for n in range(9)]
data
# Out:
# [0.800000000000000,
#  0.448000000000000,
#  0.692428800000000,
#  0.596319239405568,
#  0.674023291536932,
#  0.615204503207425,
#  0.662838182834045,
#  0.625754433391657,
#  0.655720302950561]

# %%
plot(data)
# Out:
# Graphics object consisting of 9 graphics primitives
